# %% [markdown]
# <a href="https://colab.research.google.com/github/Cheetah-lhp/MachineLearning/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(10)
def f(x):
  return 2*x + 1

X = np.random.randn(20)
Y = f(X) + np.random.randn(20) * 0.5

print(X)
print(Y)
# Out:
# [ 1.3315865   0.71527897 -1.54540029 -0.00838385  0.62133597 -0.72008556
#   0.26551159  0.10854853  0.00429143 -0.17460021  0.43302619  1.20303737
#  -0.96506567  1.02827408  0.22863013  0.44513761 -1.13660221  0.13513688
#   1.484537   -1.07980489]
# [ 2.67430887  1.5588718  -1.9577655   2.17571597  2.80451757  0.39613999
#   1.58059778  1.91609524  0.87295887  0.95740167  1.73239379  3.13142024
#  -0.86377719  2.81847715  2.1114968   1.98778187 -1.07309943  1.10145759
#   4.59731014 -1.52559452]

# %%
import matplotlib.pyplot as plt
plt.scatter([X], Y)
plt.show()

# %%
from sklearn import datasets, linear_model

# fit the model by Linear Regression
regr = linear_model.LinearRegression()
regr.fit(X.reshape(-1, 1), Y.reshape(-1, 1))

regr_lasso = linear_model.Lasso(alpha=0.1)
regr_lasso.fit(X.reshape(-1, 1), Y.reshape(-1, 1))

regr_ridge = linear_model.Ridge(alpha=0.1)
regr_ridge.fit(X.reshape(-1, 1), Y.reshape(-1, 1))

# Compare two results
print('Linear Regression model: ', regr.coef_, regr.intercept_ )
print('Lasso model: ', regr_lasso.coef_, regr_lasso.intercept_)
print('Ridge model: ', regr_ridge.coef_, regr_ridge.intercept_)
# Out:
# Linear Regression model:  [[1.85192472]] [1.1299759]
# Lasso model:  [1.7086833] [1.14698144]
# Ridge model:  [1.83875543] [1.13153935]

# %%
plt.scatter([X], Y)
x_draw = np.array([min(X), max(X)])
y_draw = regr.coef_[0] * x_draw + regr.intercept_
y_draw_lasso = regr_lasso.coef_[0] * x_draw + regr_lasso.intercept_
y_draw_ridge = regr_ridge.coef_[0] * x_draw + regr_ridge.intercept_
print(x_draw)
print(y_draw)
plt.plot(x_draw, y_draw, 'r', label = 'Linear regression')
plt.plot(x_draw, y_draw_lasso, 'g', label = 'Lasso regression')
plt.plot(x_draw, y_draw_ridge, 'b', label = 'Ridge regression')
plt.legend()
plt.show()
# Out:
# [-1.54540029  1.484537  ]
# [-1.73198912  3.87922667]

# %%
lamda = float(input())

regr_lasso = linear_model.Lasso(alpha=lamda)
regr_lasso.fit(X.reshape(-1, 1), Y.reshape(-1, 1))

plt.scatter([X], Y)
x_draw = np.array([min(X), max(X)])
y_draw_lasso = regr_lasso.coef_[0] * x_draw + regr_lasso.intercept_
plt.plot(x_draw, y_draw_lasso, 'g', label = 'Lasso regression')
plt.show()
# Out:
# 0.1
